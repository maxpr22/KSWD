# %% [markdown]
# Завдання 1
#
# Побудуйте гістограму кількості днів кожного типу погоди в Сіетлі, де:
#
# верхні краї стовпців — заокруглені;
#
# порядок по частоті (від найчастішої до найрідшої погоди);
#
# колір — залежить від типу погоди.

# %%
import altair as alt
from vega_datasets import data

# %%
source = data.seattle_weather()

source
# Out:
#            date  precipitation  temp_max  temp_min  wind  weather
# 0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1    2012-01-02           10.9      10.6       2.8   4.5     rain
# 2    2012-01-03            0.8      11.7       7.2   2.3     rain
# 3    2012-01-04           20.3      12.2       5.6   4.7     rain
# 4    2012-01-05            1.3       8.9       2.8   6.1     rain
# ...         ...            ...       ...       ...   ...      ...
# 1456 2015-12-27            8.6       4.4       1.7   2.9      fog
# 1457 2015-12-28            1.5       5.0       1.7   1.3      fog
# 1458 2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
chart1 = alt.Chart(source).mark_bar(
    cornerRadiusTopLeft=5,
    cornerRadiusTopRight=5
).encode(
    x=alt.X('weather:N', sort='-y'),
    y='count():Q',
    color='weather:N'
).properties(
    title="Кількість днів кожного типу погоди (із заокругленням)"
)

chart1
# Out:
# alt.Chart(...)

# %% [markdown]
#  Завдання 2
#
# Побудуйте горизонтальну стовпчикову діаграму врожайності сорту ячменю по місцях у 1931 році:
#
# по осі Y — сорти;
#
# колір — місце вирощування;
#
# дані — лише за 1931 рік;
#
# сортування по врожайності.

# %%
source = data.barley()

source
# Out:
#         yield           variety  year             site
# 0    27.00000         Manchuria  1931  University Farm
# 1    48.86667         Manchuria  1931           Waseca
# 2    27.43334         Manchuria  1931           Morris
# 3    39.93333         Manchuria  1931        Crookston
# 4    32.96667         Manchuria  1931     Grand Rapids
# ..        ...               ...   ...              ...
# 115  58.16667  Wisconsin No. 38  1932           Waseca
# 116  47.16667  Wisconsin No. 38  1932           Morris
# 117  35.90000  Wisconsin No. 38  1932        Crookston
# 118  20.66667  Wisconsin No. 38  1932     Grand Rapids
# 119  29.33333  Wisconsin No. 38  1932           Duluth
#
# [120 rows x 4 columns]

# %%
chart2 = alt.Chart(source).transform_filter(
    alt.datum.year == 1931
).mark_bar().encode(
    x='yield:Q',
    y=alt.Y('variety:N', sort='-x'),
    color='site:N'
).properties(
    title="Врожайність ячменю у 1931 році по сортах"
)

chart2
# Out:
# alt.Chart(...)

# %% [markdown]
#  Завдання 3
#
# Побудуйте гістограму кількості днів певного типу погоди по місяцях:
#
# по осі X — місяці;
#
# по осі Y — кількість;
#
# колір — тип погоди;
#
# групування: по типу погоди в кожному місяці (груповані стовпчики).

# %%
source = data.seattle_weather()

chart3 = alt.Chart(source).mark_bar().encode(
    x=alt.X('month(date):O', title='Місяць'),
    y='count():Q',
    color='weather:N',
    column='weather:N'
).properties(
    title="Кількість днів кожного типу погоди по місяцях"
)

chart3
# Out:
# alt.Chart(...)

# %% [markdown]
#  Завдання 4
#
# Побудуйте лінійно-обласну діаграму цін акцій:
#
# відобразіть лише компанії "GOOG" та "AAPL";
#
# колір градієнтний залежно від ціни;
#
# поверх градієнта — лінія.

# %%
source = data.stocks()

filtered = source[source['symbol'].isin(['GOOG', 'AAPL'])]

chart4 = alt.Chart(filtered).mark_area(
    line=True,
    color=alt.Gradient(
        gradient='linear',
        stops=[
            alt.GradientStop(color='white', offset=0),
            alt.GradientStop(color='steelblue', offset=1)
        ],
        x1=1, x2=1, y1=1, y2=0
    )
).encode(
    x='date:T',
    y='price:Q',
    color='symbol:N'
).properties(
    title="Ціни акцій GOOG і AAPL з градієнтом"
)

chart4
# Out:
# alt.Chart(...)

# %% [markdown]
#  Завдання 5
#
# Побудуйте потоковий граф (stack='center') рівня безробіття в різних галузях:
#
# використовуйте data.unemployment_across_industries.url;
#
# по осі X — дата;
#
# по осі Y — кількість безробітних;
#
# колір — назва галузі;
#
# додайте можливість взаємодії (інтерактивність).

# %%
source = data.unemployment_across_industries.url

chart5 = alt.Chart(source).mark_area().encode(
    x=alt.X('yearmonth(date):T', axis=alt.Axis(format='%Y')),
    y=alt.Y('sum(count):Q', stack='center', axis=None),
    color=alt.Color('series:N', scale=alt.Scale(scheme='category20b'))
).interactive().properties(
    width=700,
    height=400,
    title="Рівень безробіття в США по галузях"
)

chart5
# Out:
# alt.Chart(...)

# %% [markdown]
#  Завдання 6
#
# На основі data.seattle_weather() побудуйте:
#
# частки кожного типу погоди у вигляді кільцевої діаграми;
#
# покажіть у центрі кільце середнє значення температури;
#
# використовуйте mark_arc з innerRadius.

# %%
source = data.seattle_weather()

weather_counts = source.groupby('weather').size().reset_index(name='count')

chart6 = alt.Chart(weather_counts).mark_arc(innerRadius=50).encode(
    theta='count:Q',
    color='weather:N'
).properties(
    title="Типи погоди у Сіетлі — кільцева діаграма"
)

chart6
# Out:
# alt.Chart(...)

# %% [markdown]
# Графік на вибір

# %%
source = data.seattle_weather()

chart7 = alt.Chart(source).mark_rect().encode(
    x=alt.X('date(date):O', title='День місяця'),
    y=alt.Y('month(date):O', title='Місяць'),
    color=alt.Color('max(temp_max):Q', scale=alt.Scale(scheme='magma'), title='Макс. температура'),
    tooltip=[
        alt.Tooltip('monthdate(date):T', title='Дата'),
        alt.Tooltip('temp_max:Q', title='Макс. температура (°C)'),
        alt.Tooltip('weather:N', title='Погода')
    ]
).properties(
    width=600,
    height=300,
    title="Теплова карта максимальних температур у Сіетлі"
).interactive()

chart7
# Out:
# alt.Chart(...)
